# %%
import os
os.chdir('drive/MyDrive/thermal')

# %%
ls
# Out:
# thermal.ipynb  yolov5/

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17270, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 17270 (delta 0), reused 0 (delta 0), pack-reused 17269 (from 2)
# Receiving objects: 100% (17270/17270), 16.10 MiB | 11.96 MiB/s, done.
# Resolving deltas: 100% (11855/11855), done.
# Updating files: 100% (146/146), done.

# %%
os.chdir('yolov5')

# %%
ls
# Out:
# benchmarks.py    data/      export.py   __pycache__/     requirements.txt  tutorial.ipynb
# CITATION.cff     datasets/  hubconf.py  pyproject.toml   runs/             utils/
# classify/        data.yaml  LICENSE     README.md        segment/          val.py
# CONTRIBUTING.md  detect.py  models/     README.zh-CN.md  train.py          yolov5s.pt

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: gitpython>=3.1.30 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 5)) (3.1.44)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 6)) (3.10.0)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 7)) (1.26.4)
# Requirement already satisfied: opencv-python>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 8)) (4.11.0.86)
# Requirement already satisfied: pillow>=10.3.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 9)) (11.1.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 10)) (5.9.5)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 11)) (6.0.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 12)) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 13)) (1.13.1)
# Requirement already satisfied: thop>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 14)) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 15)) (2.5.1+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 16)) (0.20.1+cu124)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 17)) (4.67.1)
# Requirement already satisfied: ultralytics>=8.2.34 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 18)) (8.3.82)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 27)) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 28)) (0.13.2)
# Requirement already satisfied: setuptools>=70.0.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 42)) (75.1.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython>=3.1.30->-r requirements.txt (line 5)) (4.0.12)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->-r requirements.txt (line 15)) (1.3.0)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics>=8.2.34->-r requirements.txt (line 18)) (9.0.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics>=8.2.34->-r requirements.txt (line 18)) (2.0.14)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2025.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r requirements.txt (line 5)) (5.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->-r requirements.txt (line 15)) (3.0.2)

# %%
# !ls /content/drive/MyDrive/thermal/yolov5/datasets/
# Out:
# labeled_test	README.dataset.txt   test   train.cache
# labelled_train	README.roboflow.txt  train  valid

# %%
ls
# Out:
# benchmarks.py    data/      export.py   __pycache__/     requirements.txt  tutorial.ipynb
# CITATION.cff     datasets/  hubconf.py  pyproject.toml   runs/             utils/
# classify/        data.yaml  LICENSE     README.md        segment/          val.py
# CONTRIBUTING.md  detect.py  models/     README.zh-CN.md  train.py          yolov5s.pt

# %%
# !python train.py --data data.yaml --cfg yolov5s.yaml --batch-size 8 --name Model --epochs 30
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-03-03 13:42:11.107735: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741009331.141732    2036 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741009331.151995    2036 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout) 3
# wandb: You chose "Don't visualize my results"
# train: weights=yolov5s.pt, cfg=yolov5s.yaml, data=data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=30, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=Model, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# YOLOv5s summary: 214 layers, 7022326 parameters, 7022326 gradients, 15.9 GFLOPs
#
# Transferred 342/349 items from yolov5s.pt
# /content/drive/MyDrive/thermal/yolov5/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /content/drive/MyDrive/thermal/yolov5/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: 6 validation errors for InitSchema
# p
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# scale
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# ratio
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# size
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# interpolation
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# mask_interpolation
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# train: Scanning /content/drive/MyDrive/thermal/yolov5/datasets/train.cache... 402 images, 0 backgrounds, 0 corrupt: 100% 402/402 [00:00<?, ?it/s]
# val: Scanning /content/drive/MyDrive/thermal/yolov5/datasets/train.cache... 402 images, 0 backgrounds, 0 corrupt: 100% 402/402 [00:00<?, ?it/s]
#
# AutoAnchor: 4.77 anchors/target, 0.999 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/Model3/labels.jpg...
# /content/drive/MyDrive/thermal/yolov5/train.py:355: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=amp)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/Model3
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/51 [00:00<?, ?it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29      1.89G     0.1255    0.04458          0         50        640:   2% 1/51 [00:23<19:18, 23.17s/it]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29      1.94G     0.1225    0.04272          0         32        640:   4% 2/51 [00:23<07:57,  9.75s/it]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29      1.94G     0.1231    0.04302          0         44        640:   6% 3/51 [00:23<04:24,  5.51s/it]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29      1.94G     0.1225    0.04432          0         52        640:   8% 4/51 [00:24<02:46,  3.53s/it]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29      1.94G      0.123    0.04311          0         39        640:  10% 5/51 [00:24<01:48,  2.36s/it]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29      1.94G     0.1225    0.04251          0         33        640:  12% 6/51 [00:25<01:15,  1.69s/it]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29      1.94G     0.1221    0.04218          0         37        640:  14% 7/51 [00:25<00:54,  1.23s/it]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29      1.94G     0.1223     0.0418          0         33        640:  16% 8/51 [00:25<00:38,  1.12it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29      1.94G      0.123    0.04031          0         13        640:  18% 9/51 [00:26<00:33,  1.25it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29      1.94G     0.1229    0.03922          0         19        640:  20% 10/51 [00:26<00:27,  1.51it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29      1.94G     0.1228    0.03918          0         34        640:  22% 11/51 [00:27<00:24,  1.63it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29      1.94G     0.1224    0.03962          0         46        640:  24% 12/51 [00:27<00:18,  2.12it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29      1.94G     0.
/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29      2.37G    0.02605    0.02284          0         28        640:  39% 20/51 [00:04<00:08,  3.74it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29      2.37G    0.02613    0.02313          0         44        640:  41% 21/51 [00:05<00:08,  3.63it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29      2.37G    0.02614    0.02333          0         46        640:  43% 22/51 [00:05<00:06,  4.30it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29      2.37G    0.02625    0.02324          0         35        640:  45% 23/51 [00:05<00:07,  3.78it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29      2.37G    0.02612    0.02305          0         35        640:  47% 24/51 [00:05<00:06,  4.18it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29      2.37G    0.02617     0.0236          0         51        640:  49% 25/51 [00:06<00:11,  2.28it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29      2.37G    0.02604    0.02333          0         25        640:  51% 26/51 [00:07<00:11,  2.19it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29      2.37G    0.02611    0.02346          0         44        640:  53% 27/51 [00:08<00:14,  1.70it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29      2.37G    0.02626    0.02364          0         43        640:  55% 28/51 [00:08<00:12,  1.88it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29      2.37G    0.02627    0.02345          0         31        640:  57% 29/51 [00:09<00:10,  2.03it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29      2.37G     0.0262    0.02341          0         46        640:  59% 30/51 [00:09<00:09,  2.31it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29      2.37G    0.02621    0.02347          0         43        640:  61% 31/51 [00:09<00:09,  2.20it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29      2.37G    0.02617     0.0234          0         37        640:  63% 32/51 [00:10<00:07,  2.51it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29      2.37G    0.02613     0.0233          0         26        640:  65% 33/51 [00:10<00:07,  2.27it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29      2.37G    0.02608    0.02323          0         39        640:  67% 34/51 [00:10<00:06,  2.64it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29      2.37G    0.02595    0.02322          0         40        640:  69% 35/51 [00:11<00:06,  2.61it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29      2.37G    0.02591    0.02315          0         39        640:  71% 36/51 [00:11<00:04,  3.12it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29      2.37G    0.02597    0.02312          0         37        640:  73% 37/51 [00:11<00:04,  3.05it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29      2.37G    0.02597    0.02316          0         43        640:  75% 38/51 [00:11<00:03,  3.51it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29      2.37G    0.02592    0.02321          0         38        640:  76% 39/51 [00:12<00:03,  3.40it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29      2.37G    0.02595    0.02353          0         56        640:  78% 40/51 [00:12<00:02,  3.86it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29      2.37G    0.02588    0.02366          0         46        640:  80% 41/51 [00:12<00:02,  3.55it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29      2.37G    0.02589    0.02361          0         35        640:  82% 42/51 [00:12<00:02,  3.94it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29      2.37G     0.0259    0.02344          0         29        640:  84% 43/51 [00:13<00:02,  3.75it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29      2.37G    0.02592    0.02348          0         38        640:  86% 44/51 [00:13<00:01,  4.44it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29      2.37G    0.02599    0.02336          0         31        640:  88% 45/51 [00:13<00:01,  4.36it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29      2.37G    0.02597    0.02334          0         34        640:  90% 46/51 [00:13<00:01,  4.30it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29      2.37G    0.02611     0.0233          0         27        640:  92% 47/51 [00:14<00:01,  3.58it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29      2.37G    0.02608    0.02341          0         45        640:  94% 48/51 [00:14<00:00,  3.54it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29      2.37G    0.02604    0.02339          0         37        640:  96% 49/51 [00:14<00:00,  3.24it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29      2.37G    0.02602    0.02346          0         47        640:  98% 50/51 [00:15<00:00,  3.31it/s]/content/drive/MyDrive/thermal/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29      2.37G      0.026    0.02363          0         12        640: 100% 51/51 [00:15<00:00,  3.31it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 26/26 [00:06<00:00,  4.00it/s]
#                    all        402       1202       0.94      0.957       0.98      0.742
#
# 30 epochs completed in 0.195 hours.
# Optimizer stripped from runs/train/Model3/weights/last.pt, 14.4MB
# Optimizer stripped from runs/train/Model3/weights/best.pt, 14.4MB
#
# Validating runs/train/Model3/weights/best.pt...
# Fusing layers...
# YOLOv5s summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 26/26 [00:08<00:00,  3.04it/s]
#                    all        402       1202       0.95      0.941      0.979      0.743
# Results saved to runs/train/Model3

# %%
# !python export.py --weights /content/drive/MyDrive/ppe_smart_construction/yolov5/runs/train/Model4/weights/best.pt --include torchscript onnx
# Out:
# export: data=data/coco128.yaml, weights=['/content/drive/MyDrive/ppe_smart_construction/yolov5/runs/train/Model4/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, per_tensor=False, dynamic=False, cache=, simplify=False, mlmodel=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['torchscript', 'onnx']
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.11.11 torch-2.5.1+cu124 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7066762 parameters, 0 gradients, 15.9 GFLOPs
#
# PyTorch: starting from /content/drive/MyDrive/ppe_smart_construction/yolov5/runs/train/Model4/weights/best.pt with output shape (1, 25200, 26) (13.9 MB)
#
# TorchScript: starting export with torch 2.5.1+cu124...
# TorchScript: export success ✅ 6.1s, saved as /content/drive/MyDrive/ppe_smart_construction/yolov5/runs/train/Model4/weights/best.torchscript (27.4 MB)
# requirements: Ultralytics requirement ['onnx>=1.12.0'] not found, attempting AutoUpdate...
# Collecting onnx>=1.12.0
#   Downloading onnx-1.17.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.11/dist-packages (from onnx>=1.12.0) (1.26.4)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.11/dist-packages (from onnx>=1.12.0) (4.25.6)
# Downloading onnx-1.17.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 146.9 MB/s eta 0:00:00
# Installing collected packages: onnx
# Successfully installed onnx-1.17.0
#
# requirements: AutoUpdate success ✅ 4.7s, installed 1 package: ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.17.0...
# ONNX: export success ✅ 8.7s, saved as /content/drive/MyDrive/ppe_smart_construction/yolov5/runs/train/Model4/weights/best.onnx (27.4 MB)
#
# Export complete (24.9s)
# Results saved to /content/drive/MyDrive/ppe_smart_construction/yolov5/runs/train/Model4/weights
# Detect:          python detect.py --weights /content/drive/MyDrive/ppe_smart_construction/yolov5/runs/train/Model4/weights/best.onnx
# Validate:        python val.py --weights /content/drive/MyDrive/ppe_smart_construction/yolov5/runs/train/Model4/weights/best.onnx
# PyTorch Hub:     model = torch.hub.load('ultralytics/yolov5', 'custom', '/content/drive/MyDrive/ppe_smart_construction/yolov5/runs/train/Model4/weights/best.onnx')
# Visualize:       https://netron.app

# %%
# !python export.py --weights /content/drive/MyDrive/ppe_smart_construction/yolov5/runs/train/Model4/weights/best.pt --include torchscript  tflite
# Out:
# export: data=data/coco128.yaml, weights=['/content/drive/MyDrive/ppe_smart_construction/yolov5/runs/train/Model4/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, per_tensor=False, dynamic=False, cache=, simplify=False, mlmodel=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['torchscript', 'tflite']
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.11.11 torch-2.5.1+cu124 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7066762 parameters, 0 gradients, 15.9 GFLOPs
#
# PyTorch: starting from /content/drive/MyDrive/ppe_smart_construction/yolov5/runs/train/Model4/weights/best.pt with output shape (1, 25200, 26) (13.9 MB)
#
# TorchScript: starting export with torch 2.5.1+cu124...
# TorchScript: export success ✅ 2.4s, saved as /content/drive/MyDrive/ppe_smart_construction/yolov5/runs/train/Model4/weights/best.torchscript (27.4 MB)
# 2025-03-03 13:55:15.263622: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741010115.281879    7052 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741010115.287654    7052 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
#
# TensorFlow SavedModel: starting export with tensorflow 2.18.0...
# WARNING ⚠️ using Tensorflow 2.18.0 > 2.13.1 might cause issue when exporting the model to tflite https://github.com/ultralytics/yolov5/issues/12489
#
#                  from  n    params  module                                  arguments
# 2025-03-03 13:55:20.273993: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  1    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     70122  models.yolo.Detect                      [21, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512], [640, 640]]
# Model: "functional_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_15            │ (1, 640, 640, 3)       │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ tf_conv (TFConv)          │ (1, 320, 320, 32)      │          3,488 │ input_layer_15[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ tf_conv_1 (TFConv)        │ (1, 160, 160, 64)      │         18,496 │ tf_conv[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ tfc3 (TFC3)               │ (1, 160, 160, 64)      │         18,624 │ tf_conv_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ tf_conv_7 (TFConv)        │ (1, 80, 80, 128)       │         73,856 │ tfc3[0][0]             │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ tfc3_1 (TFC3)             │ (1, 80, 80, 128)       │        115,200 │ tf_conv_7[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ tf_conv_15 (TFConv)       │ (1, 40, 40, 256)       │        295,168 │ tfc3_1[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ tfc3_2 (TFC3)             │ (1, 40, 40, 256)       │        623,872 │ tf_conv_15[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ tf_conv_25 (TFConv)       │ (1, 20, 20, 512)       │      1,180,160 │ tfc3_2[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ tfc3_3 (TFC3)             │ (1, 20, 20, 512)       │      1,181,184 │ tf_conv_25[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ tfsppf (TFSPPF)           │ (1, 20, 20, 512)       │        656,128 │ tfc3_3[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ tf_conv_33 (TFConv)       │ (1, 20, 20, 256)       │        131,328 │ tfsppf[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ tf_upsample (TFUpsample)  │ (1, 40, 40, 256)       │              0 │ tf_conv_33[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ tf_concat (TFConcat)      │ (1, 40, 40, 512)       │              0 │ tf_upsample[0][0],     │
# │                           │                        │                │ tfc3_2[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ tfc3_4 (TFC3)             │ (1, 40, 40, 256)       │        361,216 │ tf_concat[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ tf_conv_39 (TFConv)       │ (1, 40, 40, 128)       │         32,896 │ tfc3_4[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ tf_upsample_1             │ (1, 80, 80, 128)       │              0 │ tf_conv_39[0][0]       │
# │ (TFUpsample)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ tf_concat_1 (TFConcat)    │ (1, 80, 80, 256)       │              0 │ tf_upsample_1[0][0],   │
# │                           │                        │                │ tfc3_1[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ tfc3_5 (TFC3)             │ (1, 80, 80, 128)       │         90,496 │ tf_concat_1[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ tf_conv_45 (TFConv)       │ (1, 40, 40, 128)       │        147,584 │ tfc3_5[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ tf_concat_2 (TFConcat)    │ (1, 40, 40, 256)       │              0 │ tf_conv_45[0][0],      │
# │                           │                        │                │ tf_conv_39[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ tfc3_6 (TFC3)             │ (1, 40, 40, 256)       │        295,680 │ tf_concat_2[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ tf_conv_51 (TFConv)       │ (1, 20, 20, 256)       │        590,080 │ tfc3_6[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ tf_concat_3 (TFConcat)    │ (1, 20, 20, 512)       │              0 │ tf_conv_51[0][0],      │
# │                           │                        │                │ tf_conv_33[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ tfc3_7 (TFC3)             │ (1, 20, 20, 512)       │      1,181,184 │ tf_concat_3[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ tf_detect (TFDetect)      │ (1, 25200, 26)         │         70,122 │ tfc3_5[0][0],          │
# │                           │                        │                │ tfc3_6[0][0],          │
# │                           │                        │                │ tfc3_7[0][0]           │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 7,066,762 (26.96 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 7,066,762 (26.96 MB)
# I0000 00:00:1741010125.401748    7052 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1741010125.401923    7052 single_machine.cc:361] Starting new session
# TensorFlow SavedModel: export success ✅ 15.1s, saved as /content/drive/MyDrive/ppe_smart_construction/yolov5/runs/train/Model4/weights/best_saved_model (27.3 MB)
#
# TensorFlow Lite: starting export with tensorflow 2.18.0...
# Saved artifact at '/tmp/tmpmuw1gs80'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(1, 640, 640, 3), dtype=tf.float32, name='keras_tensor_121')
# Output Type:
#   TensorSpec(shape=(1, 25200, 26), dtype=tf.float32, name=None)
# Captures:
#   132271223557008: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   132271223567184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271223567568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271223560848: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   132271223566992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271223567952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271174258128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271174257744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271174258704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271174257552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271174258320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271174256208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271174257936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271174259088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271174259280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271174259472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271223564688: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   132271174261584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271174258512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271174265808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271174265424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271174266384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271174265232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271174266000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271174264272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271174265616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271174266768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271174266960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271174267152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271174267344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271174267536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271174267728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271174267920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271223565456: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   132271174268496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271174265040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822658256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822657872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822658832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822657680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822658448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822657296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822658064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822659216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822659408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822659600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822659792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822659984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822660176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822660368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822660560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822660752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822660944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822661136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271223565840: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   132270822657488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822659024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822665744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822665360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822666320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822665168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822665936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822664016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822665552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822666704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822666896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822667088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822669008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822668624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822669584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822669968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822669392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822668816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822149968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822149584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822150544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822149392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822150160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822148240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822149776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822150928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822151120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822151312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822151888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822152656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822156496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822156112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822157072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822155920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822156688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822154768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822156304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822157456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822157648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822157840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271223566224: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   132270822158416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822158800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822162256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822160912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822161872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270822162064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270819690256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270819688528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270819689104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270819688720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270819689872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270819688912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271223566608: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   132270819690640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270819691024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270819694864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270819694480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270819695440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270819694288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270819695056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270819693136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270819694672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270819695824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270819696016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270819696208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270819698128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270819695248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271223566032: TensorSpec(shape=(3,), dtype=tf.float32, name=None)
#   132271223569296: TensorSpec(shape=(1, 1, 6400, 2), dtype=tf.float32, name=None)
#   132271223567376: TensorSpec(shape=(3, 1, 3, 1, 2), dtype=tf.float32, name=None)
#   132270819698704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270819697744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271223568336: TensorSpec(shape=(1, 1, 1600, 2), dtype=tf.float32, name=None)
#   132270819698320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132270819697168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132271223568144: TensorSpec(shape=(1, 1, 400, 2), dtype=tf.float32, name=None)
# W0000 00:00:1741010137.371272    7052 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1741010137.371302    7052 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1741010137.468078    7052 mlir_graph_optimization_pass.cc:401] MLIR V1 optimization pass is not enabled
# TensorFlow Lite: export success ✅ 11.3s, saved as /content/drive/MyDrive/ppe_smart_construction/yolov5/runs/train/Model4/weights/best-fp16.tflite (13.6 MB)
#
# Export complete (30.0s)
# Results saved to /content/drive/MyDrive/ppe_smart_construction/yolov5/runs/train/Model4/weights
# Detect:          python detect.py --weights /content/drive/MyDrive/ppe_smart_construction/yolov5/runs/train/Model4/weights/best-fp16.tflite
# Validate:        python val.py --weights /content/drive/MyDrive/ppe_smart_construction/yolov5/runs/train/Model4/weights/best-fp16.tflite
# PyTorch Hub:     model = torch.hub.load('ultralytics/yolov5', 'custom', '/content/drive/MyDrive/ppe_smart_construction/yolov5/runs/train/Model4/weights/best-fp16.tflite')
# Visualize:       https://netron.app
