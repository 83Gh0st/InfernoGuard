# %%
import os
from glob import glob # extract path of each file
import pandas as pd # data preprocessing
from xml.etree import ElementTree as et # parse information from XML
from functools import reduce

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# step-1: get path of each xml file
xmlfiles = glob('/home/cpow/Desktop/thermal/datasets/labelled_train/*.xml')
# replace \\ with /
replace_text = lambda x: x.replace('\\','/')
xmlfiles = list(map(replace_text,xmlfiles))

# %%
xmlfiles
# Out:
# ['/home/cpow/Desktop/thermal/datasets/labelled_train/Dublin-Fire-Brigade-FLIR-Thermal-Drone-RPAS-0-3-screenshot_png_jpg.rf.8a78661b805f434845aca700ecbd1802.xml',
#  '/home/cpow/Desktop/thermal/datasets/labelled_train/163_jpg.rf.061a5e83aa901933bf3d7204ec944865.xml',
#  '/home/cpow/Desktop/thermal/datasets/labelled_train/Automated-Fire-Suppression-System-Relies-on-FLIR-Thermal-Imaging-Cameras-2-13-screenshot-6-_png_jpg.rf.b99812557fb05dee66dec0e7a516ea12.xml',
#  '/home/cpow/Desktop/thermal/datasets/labelled_train/Fire-Assessment-w_-FLIR-Thermal-2-3-screenshot_png_jpg.rf.0b1a84d2ef2cb10b8ce3d75e6f426683.xml',
#  '/home/cpow/Desktop/thermal/datasets/labelled_train/168_jpg.rf.3899f3381c5a872d1facca43103c8a5d.xml',
#  '/home/cpow/Desktop/thermal/datasets/labelled_train/Automated-Fire-Suppression-System-Relies-on-FLIR-Thermal-Imaging-Cameras-1-47-screenshot-3-_png_jpg.rf.999df52dab81bc46ddcf942a6a2b14cc.xml',
#  '/home/cpow/Desktop/thermal/datasets/labelled_train/Vodka-shot-on-fire-Thermal-camera-footage-0-6-screenshot-2-_png_jpg.rf.53a11300d5a27164b475bf6f3944b085.xml',
#  '/home/cpow/Desktop/thermal/datasets/labelled_train/Fire-Assessment-w_-FLIR-Thermal-2-16-screenshot-1-_png_jpg.rf.ea8b54ed314d5c3c4388e05c3920b270.xml',
#  '/home/cpow/Desktop/thermal/datasets/labelled_train/Fire-Assessment-w_-FLIR-Thermal-2-9-screenshot-2-_png_jpg.rf.f087be0a30f9af286af7f016700ba350.xml',
#  '/home/cpow/Desktop/thermal/datasets/labelled_train/001-How-To-See-The-Heat-Generated-From-Fire-Science-Experiments-Explained-1-38-screenshot-1-_png_jpg.rf.77af4f238e8192533295e3252491a13a.xml',
#  '/home/cpow/Desktop/thermal/datasets/labelled_train/Automated-Fire-Suppression-System-Relies-on-FLIR-Thermal-Imaging-Cameras-2-40-screenshot-10-_png_jpg.rf.3883578ef1f6a31b96ac5f1f6696e296.xml',
#  '/home/cpow/Desktop/thermal/datasets/labelled_train/Automated-Fire-Suppression-System-Relies-on-FLIR-Thermal-Imaging-Cameras-2-3-screenshot-5-_png_jpg.rf.af0189629c87155ce40cc3c4c5659e65.xml',
#  '/home/cpow/Desktop/thermal/datasets/labelled_train/Automated-Fire-Suppression-System-Relies-on-FLIR-Thermal-Imaging-Cameras-2-12-screenshot-2-_png_jpg.rf.3ff8b230887d3320ffe3945ed24d9058.xml',
#  '/home/cpow/Desktop/thermal/datasets/labelled_train/226_jpg.rf.af1c4906e809b66e09e480728fbd92aa.xml',
#  '/home/cpow/Desktop/thermal/datasets/labelled_train/fire-works-in-infrared-0-24-screenshot_png_jpg.rf.a072ac8fe6069420062352b7e5ea5add.xml',
#  '/home/cpow/Desktop/thermal/datasets/labelled_train/Dahua-Thermal-IP-Camera-Flame_Fire-Detection-0-42-screenshot-3-_png_jpg.rf.659efeabed6a1e442327e427078c3ffc.xml',
#  '/home/cpow/Desktop/thermal/datasets/labelled_train/Infrared-view-of-tire-fire-burning-in-Anderson-County-0-51-screenshot_png_jpg.rf.2f798672c1d7739863746d598c20980a.xml',
#  '/home/cpow/Desktop/thermal/datasets/labelled_train/Fire-Assessment-w_-FLIR-Thermal-1-45-screenshot_png_jpg.rf.06cc923f860a4188df0a4acdd8f94870.xml',
#  '/home/cpow/Desktop/thermal/datasets/labelled_train/Infrared-view-of-tire-fire-burning-in-Anderson-County-0-2-screenshot-1-_png_jpg.rf.fe231b3c9b68fc9abba497ef98a0c8b4.xml',
#  '/home/cpow/Desktop/thermal/datasets/labelled_train/Fire-Assessment-w_-FLIR-Thermal-1-20-screenshot_png_jpg.rf.c392dc436130fb9aa5f4f7c97ff292e5.xml',
#  '/home/cpow/Desktop/thermal/datasets/labelled_train/243_jpg.rf.5b34fa49aea3e8890f50dc2711a61871.xml',
#  '/home/cpow/Desktop/thermal/datasets/labelled_train/490_jpg.rf.4ca2a27cd2d3752cf05239ec4cd7d063.xml',
#  '/home/cpow/Desktop/thermal/datasets/labelled_train/8_jpg.rf.74a23a055304b70393cdd1422f25a613.xml',
#  '/home/cpow/Desktop/thermal/datasets/labelled_train/The-Proper-Operation-of-the-Thermal-Imaging-Camera-2-48-screenshot_png_jpg.rf.f8cc2ecd868f421f6e5006755038e272.xml',
#  '/home/cpow/Desktop/thermal/datasets/labelled_train/The-Proper-Operation-of-the-Thermal-Imaging-Camera-2-48-screenshot_png_jpg.rf.4c069b4dab0b73a15fac69c7292bf774.xml',
#  '/home/cpow/Desktop/thermal/datasets/labelled_train/The-Proper-Operation-of-the-Thermal-Imaging-Camera-2-36-screenshot-1-_png_jpg.rf.05d6cc8a987a1c8a9653bf7b44620fbd.xml',
#  '/home/cpow/Desktop/thermal/datasets/labelled_train/Automated-Fire-Suppression-System-Relies-on-FLIR-Thermal-Imaging-Cameras-1-47-screenshot-7-_png_jpg.rf.b24d8b4afbe15f0d4cc35b32af648442.xml',
#  '/home/cpow/Desktop/thermal/datasets/labelled_train/Fire-Assessment-w_-FLIR-Thermal-1-34-screenshot_png_jpg.rf.a70607c04ce953f946f3cd5244417367.xml',
#  '/home/cpow/Desktop/thermal/datasets/labelled_train/Dahua-Thermal-IP-Camera-Flame_Fire-Detection-0-45-screenshot-7-_png_jpg.rf.10ef13721553e8b42da8e35011722b7d.xml',
#  '/home/cpow/Desktop/thermal/datasets/labelled_train/116_jpg.rf.d1b18cf9af175374f4f937aa67b6b924.xml',
#  '/home/cpow/Desktop/thermal/datasets/labelled_train/Automated-Fire-Suppression-System-Relies-on-FLIR-Thermal-Imaging-Cameras-1-20-screenshot-8-_png_jpg.rf.259249b3f4843946592becc590516f72.xml',
#  '/home/cpow/Desktop/thermal/datasets/labelled_train/137_jpg.rf.531de88588981247fb913c9e62fd2a58.xml',
#  '/home/cpow/Desktop/thermal/datasets/labelled_train
dahua-Thermal-IP-Camera-Flame_Fire-Detection-0-42-screenshot-5-_png_jpg.rf.a59ff104eb68c3c69d974c41ecaff77a.xml',
#  ...]

# %%
# step-2: read xml files
# from each xml file we need to extract
# filename, size(width, height), object(name, xmin, xmax, ymin, ymax)
def extract_text(filename):
    tree = et.parse(filename)
    root = tree.getroot()

    # extract filename
    image_name = root.find('filename').text
    # width and height of the image
    width = root.find('size').find('width').text
    height = root.find('size').find('height').text
    objs = root.findall('object')
    parser = []
    for obj in objs:
        name = obj.find('name').text
        bndbox = obj.find('bndbox')
        xmin = bndbox.find('xmin').text
        xmax = bndbox.find('xmax').text
        ymin = bndbox.find('ymin').text
        ymax = bndbox.find('ymax').text
        parser.append([image_name, width, height, name,xmin,xmax,ymin,ymax])
        
    return parser

# %%
parser_all = list(map(extract_text,xmlfiles))

# %%
data = reduce(lambda x, y : x+y,parser_all)

# %%
df = pd.DataFrame(data,columns = ['filename','width','height','name','xmin','xmax','ymin','ymax'])

# %%
df.head()
# Out:
#                                             filename width height  name xmin  \
# 0  Dublin-Fire-Brigade-FLIR-Thermal-Drone-RPAS-0-...   640    640  fire  152
# 1  Dublin-Fire-Brigade-FLIR-Thermal-Drone-RPAS-0-...   640    640  fire   76
# 2    163_jpg.rf.061a5e83aa901933bf3d7204ec944865.jpg   640    640  fire  170
# 3  Automated-Fire-Suppression-System-Relies-on-FL...   640    640  fire  343
# 4  Fire-Assessment-w_-FLIR-Thermal-2-3-screenshot...   640    640  fire    1
#
#   xmax ymin ymax
# 0  208  497  550
# 1  107  351  432
# 2  515  295  570
# 3  386  253  315
# 4  191    1   66

# %%
df.shape
# Out:
# (5238, 8)

# %%
df['name'].value_counts()
# Out:
# name
# fire    5238
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5238 entries, 0 to 5237
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  5238 non-null   object
#  1   width     5238 non-null   object
#  2   height    5238 non-null   object
#  3   name      5238 non-null   object
#  4   xmin      5238 non-null   object
#  5   xmax      5238 non-null   object
#  6   ymin      5238 non-null   object
#  7   ymax      5238 non-null   object
# dtypes: object(8)
# memory usage: 327.5+ KB

# %%
# type conversion
cols = ['width','height','xmin','xmax','ymin','ymax']
df[cols] = df[cols].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5238 entries, 0 to 5237
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  5238 non-null   object
#  1   width     5238 non-null   int64
#  2   height    5238 non-null   int64
#  3   name      5238 non-null   object
#  4   xmin      5238 non-null   int64
#  5   xmax      5238 non-null   int64
#  6   ymin      5238 non-null   int64
#  7   ymax      5238 non-null   int64
# dtypes: int64(6), object(2)
# memory usage: 327.5+ KB

# %%
# center x, center y
df['center_x'] = ((df['xmax']+df['xmin'])/2)/df['width']
df['center_y'] = ((df['ymax']+df['ymin'])/2)/df['height']
# w 
df['w'] = (df['xmax']-df['xmin'])/df['width']
# h 
df['h'] = (df['ymax']-df['ymin'])/df['height']

# %%
df.head()
# Out:
#                                             filename  width  height  name  \
# 0  Dublin-Fire-Brigade-FLIR-Thermal-Drone-RPAS-0-...    640     640  fire
# 1  Dublin-Fire-Brigade-FLIR-Thermal-Drone-RPAS-0-...    640     640  fire
# 2    163_jpg.rf.061a5e83aa901933bf3d7204ec944865.jpg    640     640  fire
# 3  Automated-Fire-Suppression-System-Relies-on-FL...    640     640  fire
# 4  Fire-Assessment-w_-FLIR-Thermal-2-3-screenshot...    640     640  fire
#
#    xmin  xmax  ymin  ymax  center_x  center_y         w         h
# 0   152   208   497   550  0.281250  0.817969  0.087500  0.082812
# 1    76   107   351   432  0.142969  0.611719  0.048438  0.126562
# 2   170   515   295   570  0.535156  0.675781  0.539062  0.429688
# 3   343   386   253   315  0.569531  0.443750  0.067187  0.096875
# 4     1   191     1    66  0.150000  0.052344  0.296875  0.101562

# %%
images = df['filename'].unique()

# %%
len(images)
# Out:
# 1757

# %%
# 80% train and 20% test
img_df = pd.DataFrame(images,columns=['filename'])
img_train = tuple(img_df.sample(frac=0.8)['filename']) # shuffle and pick 80% of images

# %%
img_test = tuple(img_df.query(f'filename not in {img_train}')['filename']) # take rest 20% images

# %%
len(img_train), len(img_test)
# Out:
# (1406, 351)

# %%
train_df = df.query(f'filename in {img_train}')
test_df = df.query(f'filename in {img_test}')

# %%
train_df.head()
# Out:
#                                             filename  width  height  name  \
# 0  Dublin-Fire-Brigade-FLIR-Thermal-Drone-RPAS-0-...    640     640  fire
# 1  Dublin-Fire-Brigade-FLIR-Thermal-Drone-RPAS-0-...    640     640  fire
# 2    163_jpg.rf.061a5e83aa901933bf3d7204ec944865.jpg    640     640  fire
# 3  Automated-Fire-Suppression-System-Relies-on-FL...    640     640  fire
# 4  Fire-Assessment-w_-FLIR-Thermal-2-3-screenshot...    640     640  fire
#
#    xmin  xmax  ymin  ymax  center_x  center_y         w         h
# 0   152   208   497   550  0.281250  0.817969  0.087500  0.082812
# 1    76   107   351   432  0.142969  0.611719  0.048438  0.126562
# 2   170   515   295   570  0.535156  0.675781  0.539062  0.429688
# 3   343   386   253   315  0.569531  0.443750  0.067187  0.096875
# 4     1   191     1    66  0.150000  0.052344  0.296875  0.101562

# %%
test_df.head()
# Out:
#                                              filename  width  height  name  \
# 8     168_jpg.rf.3899f3381c5a872d1facca43103c8a5d.jpg    640     640  fire
# 14  001-How-To-See-The-Heat-Generated-From-Fire-Sc...    640     640  fire
# 22    226_jpg.rf.af1c4906e809b66e09e480728fbd92aa.jpg    640     640  fire
# 29  Dahua-Thermal-IP-Camera-Flame_Fire-Detection-0...    640     640  fire
# 34  Fire-Assessment-w_-FLIR-Thermal-1-45-screensho...    640     640  fire
#
#     xmin  xmax  ymin  ymax  center_x  center_y         w         h
# 8    182   403    32   351  0.457031  0.299219  0.345313  0.498437
# 14    81   225   452   615  0.239063  0.833594  0.225000  0.254688
# 22   578   641   566   641  0.952344  0.942969  0.098437  0.117188
# 29   368   400   233   379  0.600000  0.478125  0.050000  0.228125
# 34     1   248     1    88  0.194531  0.069531  0.385937  0.135937

# %%
def label_encoding(x):
    labels = {
        'fire': 0, 

    }
    return labels[x]

# %%
train_df['id'] = train_df['name'].apply(label_encoding)
test_df['id'] = test_df['name'].apply(label_encoding)

# %%
train_df.head(10)
# Out:
#                                              filename  width  height  name  \
# 0   Dublin-Fire-Brigade-FLIR-Thermal-Drone-RPAS-0-...    640     640  fire
# 1   Dublin-Fire-Brigade-FLIR-Thermal-Drone-RPAS-0-...    640     640  fire
# 2     163_jpg.rf.061a5e83aa901933bf3d7204ec944865.jpg    640     640  fire
# 3   Automated-Fire-Suppression-System-Relies-on-FL...    640     640  fire
# 4   Fire-Assessment-w_-FLIR-Thermal-2-3-screenshot...    640     640  fire
# 5   Fire-Assessment-w_-FLIR-Thermal-2-3-screenshot...    640     640  fire
# 6   Fire-Assessment-w_-FLIR-Thermal-2-3-screenshot...    640     640  fire
# 7   Fire-Assessment-w_-FLIR-Thermal-2-3-screenshot...    640     640  fire
# 9   Automated-Fire-Suppression-System-Relies-on-FL...    640     640  fire
# 10  Automated-Fire-Suppression-System-Relies-on-FL...    640     640  fire
#
#     xmin  xmax  ymin  ymax  center_x  center_y         w         h  id
# 0    152   208   497   550  0.281250  0.817969  0.087500  0.082812   0
# 1     76   107   351   432  0.142969  0.611719  0.048438  0.126562   0
# 2    170   515   295   570  0.535156  0.675781  0.539062  0.429688   0
# 3    343   386   253   315  0.569531  0.443750  0.067187  0.096875   0
# 4      1   191     1    66  0.150000  0.052344  0.296875  0.101562   0
# 5    333   495    49   141  0.646875  0.148438  0.253125  0.143750   0
# 6    218   333   456   578  0.430469  0.807813  0.179688  0.190625   0
# 7    333   388   613   641  0.563281  0.979688  0.085938  0.043750   0
# 9    378   440   275   319  0.639062  0.464062  0.096875  0.068750   0
# 10   136   215   583   641  0.274219  0.956250  0.123438  0.090625   0

# %%
import os
from shutil import move

# %%
train_folder = '/home/cpow/Desktop/thermal/datasets/train'
test_folder = '/home/cpow/Desktop/thermal/datasets/test'


os.mkdir(train_folder)
os.mkdir(test_folder)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[100], line 5
#       1 train_folder = '/home/cpow/Desktop/thermal/datasets/train'
#       2 test_folder = '/home/cpow/Desktop/thermal/datasets/test'
# ----> 5 os.mkdir(train_folder)
#       6 os.mkdir(test_folder)
#
# FileExistsError: [Errno 17] File exists: '/home/cpow/Desktop/thermal/datasets/train'

# %%
cols = ['filename','id','center_x','center_y', 'w', 'h']
groupby_obj_train = train_df[cols].groupby('filename')
groupby_obj_test = test_df[cols].groupby('filename')

# %%
#groupby_obj_train.get_group('000009.jpg').set_index('filename').to_csv('sample.txt',index=False,header=False)
# save each image in train/test folder and repective labels in .txt
def save_data(filename, folder_path, group_obj):
    # move image
    src = os.path.join('/home/cpow/Desktop/thermal/datasets/train',filename)
    dst = os.path.join(folder_path,filename)
    move(src,dst) # move image to the destination folder
    
    # save the labels
    text_filename = os.path.join(folder_path,
                                 os.path.splitext(filename)[0]+'.txt')
    group_obj.get_group(filename).set_index('filename').to_csv(text_filename,sep=' ',index=False,header=False)

# %%
filename_series = pd.Series(groupby_obj_train.groups.keys())

# %%
filename_series.apply(save_data,args=(train_folder,groupby_obj_train))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /usr/lib/python3.10/shutil.py:816, in move(src, dst, copy_function)
#     815 try:
# --> 816     os.rename(src, real_dst)
#     817 except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/cpow/Desktop/thermal/datasets/train/-1-_jpg.rf.02db23621ccd6faba8ed3e1c56264968.jpg' -> '/home/cpow/Desktop/thermal/datasets/train/-1-_jpg.rf.02db23621ccd6faba8ed3e1c56264968.jpg'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 filename_series.apply(save_data,args=(train_folder,groupby_obj_train))
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:1496, in SeriesApply.apply_standard.<locals>.curried(x)
#    1495 def curried(x):
# -> 1496     return func(x, *self.args, **self.kwargs)
#
# Cell In[102], line 7, in save_data(filename, folder_path, group_obj)
#       5 src = os.path.join('/home/cpow/Desktop/thermal/datasets/train',filename)
#       6 dst = os.path.join(folder_path,filename)
# ----> 7 move(src,dst) # move image to the destination folder
#       9 # save the labels
#      10 text_filename = os.path.join(folder_path,
#      11                              os.path.splitext(filename)[0]+'.txt')
#
# File /usr/lib/python3.10/shutil.py:836, in move(src, dst, copy_function)
#     834         rmtree(src)
#     835     else:
# --> 836         copy_function(src, real_dst)
#     837         os.unlink(src)
#     838 return real_dst
#
# File /usr/lib/python3.10/shutil.py:434, in copy2(src, dst, follow_symlinks)
#     432 if os.path.isdir(dst):
#     433     dst = os.path.join(dst, os.path.basename(src))
# --> 434 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     435 copystat(src, dst, follow_symlinks=follow_symlinks)
#     436 return dst
#
# File /usr/lib/python3.10/shutil.py:254, in copyfile(src, dst, follow_symlinks)
#     252     os.symlink(os.readlink(src), dst)
#     253 else:
# --> 254     with open(src, 'rb') as fsrc:
#     255         try:
#     256             with open(dst, 'wb') as fdst:
#     257                 # macOS
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/cpow/Desktop/thermal/datasets/train/-1-_jpg.rf.02db23621ccd6faba8ed3e1c56264968.jpg'

# %%
filename_series_test = pd.Series(groupby_obj_test.groups.keys())
filename_series_test.apply(save_data,args=(test_folder,groupby_obj_test))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /usr/lib/python3.10/shutil.py:816, in move(src, dst, copy_function)
#     815 try:
# --> 816     os.rename(src, real_dst)
#     817 except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/cpow/Desktop/thermal/datasets/train/-3-17-screenshot_png_jpg.rf.ba9c8b2989ef3935b2282cdaf4175169.jpg' -> '/home/cpow/Desktop/thermal/datasets/test/-3-17-screenshot_png_jpg.rf.ba9c8b2989ef3935b2282cdaf4175169.jpg'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[105], line 2
#       1 filename_series_test = pd.Series(groupby_obj_test.groups.keys())
# ----> 2 filename_series_test.apply(save_data,args=(test_folder,groupby_obj_test))
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:1496, in SeriesApply.apply_standard.<locals>.curried(x)
#    1495 def curried(x):
# -> 1496     return func(x, *self.args, **self.kwargs)
#
# Cell In[102], line 7, in save_data(filename, folder_path, group_obj)
#       5 src = os.path.join('/home/cpow/Desktop/thermal/datasets/train',filename)
#       6 dst = os.path.join(folder_path,filename)
# ----> 7 move(src,dst) # move image to the destination folder
#       9 # save the labels
#      10 text_filename = os.path.join(folder_path,
#      11                              os.path.splitext(filename)[0]+'.txt')
#
# File /usr/lib/python3.10/shutil.py:836, in move(src, dst, copy_function)
#     834         rmtree(src)
#     835     else:
# --> 836         copy_function(src, real_dst)
#     837         os.unlink(src)
#     838 return real_dst
#
# File /usr/lib/python3.10/shutil.py:434, in copy2(src, dst, follow_symlinks)
#     432 if os.path.isdir(dst):
#     433     dst = os.path.join(dst, os.path.basename(src))
# --> 434 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     435 copystat(src, dst, follow_symlinks=follow_symlinks)
#     436 return dst
#
# File /usr/lib/python3.10/shutil.py:254, in copyfile(src, dst, follow_symlinks)
#     252     os.symlink(os.readlink(src), dst)
#     253 else:
# --> 254     with open(src, 'rb') as fsrc:
#     255         try:
#     256             with open(dst, 'wb') as fdst:
#     257                 # macOS
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/cpow/Desktop/thermal/datasets/train/-3-17-screenshot_png_jpg.rf.ba9c8b2989ef3935b2282cdaf4175169.jpg'
